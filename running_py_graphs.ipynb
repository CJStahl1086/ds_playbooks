# %%
import matplotlib.pyplot as plt
import numpy as np
import tkinter as tk
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg

# Generate some data
x = np.linspace(0, 10, 100)
y = np.sin(x)

# Create a figure and add a line plot
fig, ax = plt.subplots()
ax.plot(x, y)

# Create a Tkinter window and add a canvas to it
root = tk.Tk()
canvas = FigureCanvasTkAgg(fig, master=root)
canvas.draw()
canvas.get_tk_widget().pack(side=tk.TOP, fill=tk.BOTH, expand=1)

# Start the Tkinter event loop
root.mainloop()

# %%
#jupyter nbconvert --to script your_notebook.ipynb

# %%
from nbconvert import PythonExporter
import nbformat

# Load the notebook file
nb = nbformat.read('Untitled1.ipynb', nbformat.NO_CONVERT)

# Create a PythonExporter object
exporter = PythonExporter()

# Export the notebook to a Python script
output, resources = exporter.from_notebook_node(nb)

# Write the script to a file
with open('your_script.py', 'w') as f:
    f.write(output)

# %%
# %run your_script.py
