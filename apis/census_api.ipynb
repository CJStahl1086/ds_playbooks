# %%
import requests
import json
import pandas as pd

# %%
# use (&for=state:*) for all states
url = 'https://api.census.gov/data/2014/pep/natstprc?get=STNAME,POP&DATE_=7&for=state:*'
response = requests.get(url).json()
data = pd.DataFrame(response)
data = data.rename(columns={0:'State', 1:'Population'})
data = data.drop(columns=[2,3])
data = data.drop(0).reset_index(drop=True)
data.head()
# Out:
#         State Population
# 0     Alabama    4849377
# 1      Alaska     736732
# 2     Arizona    6731484
# 3    Arkansas    2966369
# 4  California   38802500

# %%
response
# Out:
# [['DENSITY_2021', 'POP_2021', 'NAME', 'STATE', 'state'],
#  ['58.1171593930', '3986639', 'Oklahoma', '40', '40'],
#  ['25.5629643700', '1963692', 'Nebraska', '31', '31'],
#  ['224.4561379100', '1441553', 'Hawaii', '15', '15'],
#  ['11.8108489860', '895376', 'South Dakota', '46', '46'],
#  ['169.1679021400', '6975218', 'Tennessee', '47', '47'],
#  ['28.6180620940', '3143991', 'Nevada', '32', '32'],
#  ['17.4415070270', '2115877', 'New Mexico', '35', '35'],
#  ['57.1690084670', '3193079', 'Iowa', '19', '19'],
#  ['35.8932536190', '2934582', 'Kansas', '20', '20'],
#  ['10961.8457220000', '670050', 'District of Columbia', '11', '11'],
#  ['113.0182013800', '29527941', 'Texas', '48', '48'],
#  ['89.7235035990', '6168187', 'Missouri', '29', '29'],
#  ['58.1946786180', '3025891', 'Arkansas', '05', '05'],
#  ['177.5519359400', '10050811', 'Michigan', '26', '26'],
#  ['155.1295034800', '1388992', 'New Hampshire', '33', '33'],
#  ['216.9997170300', '10551162', 'North Carolina', '37', '37'],
# ...

# %%
url = f'https://api.census.gov/data/2021/pep/population?get=DENSITY_2021,POP_2021,NAME,STATE&for=state:*&key={key}'
response = requests.get(url).json()
data = pd.DataFrame(response)
data
# Out:
#                    0         1                     2      3      4
# 0       DENSITY_2021  POP_2021                  NAME  STATE  state
# 1      58.1171593930   3986639              Oklahoma     40     40
# 2      25.5629643700   1963692              Nebraska     31     31
# 3     224.4561379100   1441553                Hawaii     15     15
# 4      11.8108489860    895376          South Dakota     46     46
# 5     169.1679021400   6975218             Tennessee     47     47
# 6      28.6180620940   3143991                Nevada     32     32
# 7      17.4415070270   2115877            New Mexico     35     35
# 8      57.1690084670   3193079                  Iowa     19     19
# 9      35.8932536190   2934582                Kansas     20     20
# 10  10961.8457220000    670050  District of Columbia     11     11
# 11    113.0182013800  29527941                 Texas     48     48
# 12     89.7235035990   6168187              Missouri     29     29
# ...

# %%
url = 'https://api.census.gov/data/2016/acs/acs1?get=NAME,B01001_001E&for=state:*&key=d730d013eab77a99dd0381b238572513ba12faab'
response = requests.get(url)
data1 = response.json()
a = pd.DataFrame(data1)
a
# Out:
#                        0            1      2
# 0                   NAME  B01001_001E  state
# 1            Mississippi      2988726     28
# 2               Missouri      6093000     29
# 3                Montana      1042520     30
# 4               Nebraska      1907116     31
# 5                 Nevada      2940058     32
# 6          New Hampshire      1334795     33
# 7             New Jersey      8944469     34
# 8             New Mexico      2081015     35
# 9               New York     19745289     36
# 10        North Carolina     10146788     37
# 11          North Dakota       757953     38
# 12                  Ohio     11614373     39
# 13              Oklahoma      3923561     40
# 14                Oregon      4093465     41
# 15          Pennsylvania     12784227     42
# 16          Rhode Island      1056426     44
# 17        South Carolina      4961119     45
# 18          South Dakota       865454     46
# 19             Tennessee      6651194     47
# ...

# %%
url = 'https://api.census.gov/data/2021/pep/population?get=POP_2021,NAME,STATE&for=state:*&key=d730d013eab77a99dd0381b238572513ba12faab'
response = requests.get(url)
data1 = response.json()
a = pd.DataFrame(data1)
a
# Out:
#            0                     1      2      3
# 0   POP_2021                  NAME  STATE  state
# 1    3986639              Oklahoma     40     40
# 2    1963692              Nebraska     31     31
# 3    1441553                Hawaii     15     15
# 4     895376          South Dakota     46     46
# 5    6975218             Tennessee     47     47
# 6    3143991                Nevada     32     32
# 7    2115877            New Mexico     35     35
# 8    3193079                  Iowa     19     19
# 9    2934582                Kansas     20     20
# 10    670050  District of Columbia     11     11
# 11  29527941                 Texas     48     48
# 12   6168187              Missouri     29     29
# 13   3025891              Arkansas     05     05
# 14  10050811              Michigan     26     26
# 15   1388992         New Hampshire     33     33
# 16  10551162        North Carolina     37     37
# 17  11780017                  Ohio     39     39
# ...

# %%
url = 'https://api.census.gov/data/2019/pep/population?get=POP,NAME,STATE&for=state:*&key=d730d013eab77a99dd0381b238572513ba12faab'
response = requests.get(url)
data1 = response.json()
a = pd.DataFrame(data1)
a
# Out:
#            0                     1      2      3
# 0        POP                  NAME  STATE  state
# 1    4903185               Alabama     01     01
# 2     731545                Alaska     02     02
# 3    7278717               Arizona     04     04
# 4    3017804              Arkansas     05     05
# 5   39512223            California     06     06
# 6    5758736              Colorado     08     08
# 7     973764              Delaware     10     10
# 8     705749  District of Columbia     11     11
# 9    1787065                 Idaho     16     16
# 10   3565287           Connecticut     09     09
# 11  21477737               Florida     12     12
# 12  10617423               Georgia     13     13
# 13   1415872                Hawaii     15     15
# 14  12671821              Illinois     17     17
# 15   6732219               Indiana     18     18
# 16   3155070                  Iowa     19     19
# 17   2913314                Kansas     20     20
# ...

# %%
url = 'https://api.census.gov/data/2019/pep/charagegroups?get=POP,NAME,AGEGROUP&for=state:*&key=d730d013eab77a99dd0381b238572513ba12faab'
response = requests.get(url)
data1 = response.json()
a = pd.DataFrame(data1)
a


med = a.loc[a[2] == '31']

#'23' = (18-24 years)

# %%
med
# Out:
#          0                     1   2   3
# 32      38           Mississippi  31  28
# 64    38.9              Missouri  31  29
# 96    40.1               Montana  31  30
# 128   36.8              Nebraska  31  31
# 160   38.3                Nevada  31  32
# 192   43.1         New Hampshire  31  33
# 224   40.1            New Jersey  31  34
# 256   38.4            New Mexico  31  35
# 288   39.2              New York  31  36
# 320   39.1        North Carolina  31  37
# 352   35.3          North Dakota  31  38
# 384   39.5                  Ohio  31  39
# 416   36.9              Oklahoma  31  40
# 448   39.6                Oregon  31  41
# 480   40.8          Pennsylvania  31  42
# 512   40.1          Rhode Island  31  44
# 544   39.9        South Carolina  31  45
# 576   37.4          South Dakota  31  46
# 608     39             Tennessee  31  47
# 640     35                 Texas  31  48
# 672     43               Vermont  31  50
# 704   31.3                  Utah  31  49
# ...

# %%
url = 'https://api.census.gov/data/2018/pep/charagegroups?get=POP,GEONAME,AGEGROUP&for=state:*&key=d730d013eab77a99dd0381b238572513ba12faab'
response = requests.get(url)
data1 = response.json()
a = pd.DataFrame(data1)
a
# Out:
#             0            1         2      3
# 0         POP      GEONAME  AGEGROUP  state
# 1     4887871      Alabama         0     01
# 2      293203      Alabama         1     01
# 3      297900      Alabama         2     01
# 4      310495      Alabama         3     01
# ...       ...          ...       ...    ...
# 1660    86099  Puerto Rico        27     72
# 1661  2682764  Puerto Rico        28     72
# 1662  2601142  Puerto Rico        29     72
# 1663  1210889  Puerto Rico        30     72
# 1664       43  Puerto Rico        31     72
#
# [1665 rows x 4 columns]

# %%
url = 'https://api.census.gov/data/2019/pep/charagegroups?get=POP,GEONAME,AGEGROUP&for=state:*&key=d730d013eab77a99dd0381b238572513ba12faab'
response = requests.get(url)
data1 = response.json()
a = pd.DataFrame(data1)
a
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\requests\models.py:910, in Response.json(self, **kwargs)
#     909 try:
# --> 910     return complexjson.loads(self.text, **kwargs)
#     911 except JSONDecodeError as e:
#     912     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     913     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~\anaconda3\lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# ...

# %%
#2018 population 

url = 'https://api.census.gov/data/2018/pep/charagegroups?get=POP,GEONAME,AGEGROUP&for=state:*&key=d730d013eab77a99dd0381b238572513ba12faab'
response = requests.get(url)
data1 = response.json()
a = pd.DataFrame(data1)
a
# Out:
#             0            1         2      3
# 0         POP      GEONAME  AGEGROUP  state
# 1     4887871      Alabama         0     01
# 2      293203      Alabama         1     01
# 3      297900      Alabama         2     01
# 4      310495      Alabama         3     01
# ...       ...          ...       ...    ...
# 1660    86099  Puerto Rico        27     72
# 1661  2682764  Puerto Rico        28     72
# 1662  2601142  Puerto Rico        29     72
# 1663  1210889  Puerto Rico        30     72
# 1664       43  Puerto Rico        31     72
#
# [1665 rows x 4 columns]

# %%
#2017 population

url = 'https://api.census.gov/data/2017/pep/charagegroups?get=POP,GEONAME,AGEGROUP&for=state:*&key=d730d013eab77a99dd0381b238572513ba12faab'
response = requests.get(url)
data1 = response.json()
a = pd.DataFrame(data1)
a
# Out:
#             0              1         2      3
# 0         POP        GEONAME  AGEGROUP  state
# 1     4860545        Alabama         0     01
# 2      741522         Alaska         0     02
# 3      293581        Alabama         1     01
# 4       54664         Alaska         1     02
# ...       ...            ...       ...    ...
# 1660     42.3  West Virginia        31     54
# 1661     39.3      Wisconsin        31     55
# 1662     37.2        Wyoming        31     56
# 1663     40.8    Puerto Rico        31     72
# 1664     39.4  Massachusetts        31     25
#
# [1665 rows x 4 columns]

# %%
#2016 population 
url = 'https://api.census.gov/data/2016/pep/charagegroups?get=POP,GEONAME,AGEGROUP&for=state:*&key=d730d013eab77a99dd0381b238572513ba12faab'
response = requests.get(url)
data1 = response.json()
a = pd.DataFrame(data1)
a
# Out:
#             0          1         2      3
# 0         POP    GEONAME  AGEGROUP  state
# 1     4863300    Alabama         0     01
# 2      741894     Alaska         0     02
# 3      292565    Alabama         1     01
# 4       54115     Alaska         1     02
# ...       ...        ...       ...    ...
# 1660  2329505   Colorado        30     08
# 1661     36.6   Colorado        31     08
# 1662  1885784  Louisiana        30     22
# 1663     36.6  Louisiana        31     22
# 1664  2202512  Wisconsin        30     55
#
# [1665 rows x 4 columns]

# %%
#2015 population 
url = 'https://api.census.gov/data/2015/pep/charage?get=POP,GEONAME,AGE&for=state:*&key=d730d013eab77a99dd0381b238572513ba12faab'
response = requests.get(url)
data1 = response.json()
a = pd.DataFrame(data1)
a
# Out:
#             0                                                  1    2      3
# 0         POP                                            GEONAME  AGE  state
# 1       58017  Alabama, East South Central, South, United States    0     01
# 2       58451  Alabama, East South Central, South, United States    1     01
# 3       57924  Alabama, East South Central, South, United States    2     01
# 4       58914  Alabama, East South Central, South, United States    3     01
# ...       ...                                                ...  ...    ...
# 4535     1176                                        Puerto Rico   97     72
# 4536      972                                        Puerto Rico   98     72
# 4537      774                                        Puerto Rico   99     72
# 4538     1756                                        Puerto Rico  100     72
# 4539  3474182                                        Puerto Rico  999     72
#
# [4540 rows x 4 columns]

# %%
#
