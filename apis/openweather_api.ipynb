# %%
import requests
import json
import pandas as pd

# %%
# (https://openweathermap.org/api)
lat = '45.68'
long = '111.03'

#Current Weather API (https://openweathermap.org/current)
url = f'https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={long}&units=imperial&appid={key}'
response = requests.get(url).json()


data = pd.DataFrame.from_dict(response['main'], orient='index')
data = data.transpose()
data
# Out:
#     temp  feels_like  temp_min  temp_max  pressure  humidity  sea_level  \
# 0 -13.83      -26.43    -13.83    -13.83    1046.0      67.0     1046.0
#
#    grnd_level
# 0       897.0

# %%
data1
# Out:
# {'coord': {'lon': -111.03, 'lat': 45.68},
#  'weather': [{'id': 601,
#    'main': 'Snow',
#    'description': 'snow',
#    'icon': '13d'}],
#  'base': 'stations',
#  'main': {'temp': 32.45,
#   'feels_like': 24.42,
#   'temp_min': 31.21,
#   'temp_max': 35.2,
#   'pressure': 1006,
#   'humidity': 92},
#  'visibility': 277,
#  'wind': {'speed': 9.73, 'deg': 295, 'gust': 17.34},
#  'snow': {'1h': 0.51},
#  'clouds': {'all': 100},
#  'dt': 1666555120,
#  'sys': {'type': 2,
#   'id': 2012531,
#   'country': 'US',
#   'sunrise': 1666533083,
#   'sunset': 1666571110},
#  'timezone': -21600,
#  'id': 5641727,
#  'name': 'Bozeman',
#  'cod': 200}

# %%
#5 Day / 3 Hour Forecast Data (https://openweathermap.org/forecast5)
url = f'https://api.openweathermap.org/data/2.5/forecast?lat={lat}&lon={long}&appid={key}'
response = requests.get(url).json()
response
# Out:
# {'cod': '200',
#  'message': 0,
#  'cnt': 40,
#  'list': [{'dt': 1666558800,
#    'main': {'temp': 276.6,
#     'feels_like': 273.41,
#     'temp_min': 276.6,
#     'temp_max': 276.6,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 888,
#     'humidity': 34,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 3.52, 'deg': 218, 'gust': 4.03},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-10-23 21:00:00'},
#   {'dt': 1666569600,
#    'main': {'temp': 276.82,
#     'feels_like': 273.54,
#     'temp_min': 276.82,
#     'temp_max': 277.27,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 888,
#     'humidity': 35,
#     'temp_kf': -0.45},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
# ...
